# %% [markdown]
# # Analizising Trujillo City in terms of Amenities and locals by Clustering and Foursquare Location Data

# %% [markdown]
# # 1. Introduction
#
# ![Trujillo](https://i.imgur.com/Sq5JcVd.jpg)
#
# The third most important City in Peru is Trujillo, well known for locals and tourist as 'The city of the eternal Spring'. Trujillo has many outdoor places, and locals to socialize and have fun, whether you are a night or day person; Also, has touristic places to know better the acient culture. In the last years this city has increased its economy and its been reflected by the amount of local business and buildings around it.

# %% [markdown]
# ## 1.1 Description of the problem

# %% [markdown]
# As the city grows and develops, it is important to understand what are the main business and how those are being distribuited along the city to better undestand the wants and needs of its citizens.
#
# This project aims to analize what are the locals business Trujillo city offers to its citizens and tourist, how the locals business are distribuited along this city and what are the most common type of business per categories. Hoping this could help people that are interested in undestanding better the grow this city and also to entrepreneurs, who want to start a new business, to aswers questions like What kind of local business are missing in the city? or where could be the best place to stablish it?

# %% [markdown]
# ## 1.2 Discussion of the background

# %% [markdown]
# ## 2.1 Description of the data

# %% [markdown]
# The data to be used will be scrapped from various websites in order to analize the Trujillo city local businesses, each of them is listed in the next followings:
#
# 1. Foursquare location data: https://foursquare.com/explore?mode=url&near=Trujillo%2C%20Peru&nearGeoId=72057594041619111
# 2. Trujillo Postal codes data: https://worldpostalcode.com/peru/la-libertad/trujillo/
# 3. Foursquare Developers Access to venue data: https://developer.foursquare.com/docs/
# 4. Trujillo Census Tract Demographics: https://censusreporter.org/profiles/14000US72139060213-census-tract-60213-trujillo-alto-pr/

# %% [markdown]
# ## 2.2 How it will be used to solve the problem

# %% [markdown]
# The usage of this data will allow exporation and analysis to try to answer the previous question. The foursquare provide local data to caregorize and analize the types of local business and also show where these businesses are being concentrated and what are the most popular places in each district. The Census data will enable understand how the population density is being distribuited along the city, which districts has more people with more household income, filtering by youngs or adutls, and how we can find the best places to start a new business.
